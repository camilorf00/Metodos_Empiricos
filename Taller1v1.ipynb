# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# # Fondos de Renta Variable

# %%
data = pd.read_excel("DatosTaller1.xlsx", index_col = 0)
data.head()
# Out:
#             Dinamico  ValorCcorp  AccionesBancol  ColombiaBTG  DaviviendaC  \
# Fecha
# 2015-11-30   9649.28    10799.94    42655.128906          NaN          NaN
# 2015-12-31  10408.51    11089.46    46428.460938          NaN          NaN
# 2016-01-31  10759.11    11241.35    48226.398438          NaN          NaN
# 2016-02-29  11617.28    12838.29    50659.101563          NaN          NaN
# 2016-03-31  12272.40    13395.48    54174.289063          NaN          NaN
#
#             Ultraserfinc  Pcorfi  DividendYield  RiskFree   COLCAP
# Fecha
# 2015-11-30  47239.121094     NaN       0.003195       NaN  1114.36
# 2015-12-31  50628.289063     NaN       0.003118  0.004515  1153.71
# 2016-01-31  52680.570313     NaN       0.003069  0.004631  1175.09
# 2016-02-29  54980.441406     NaN       0.002741  0.004948  1244.17
# 2016-03-31  57705.058594     NaN       0.002534  0.005261  1336.27

# %% [markdown]
# ### Modelo Dinámico CrediCorp

# %%
CrediD = data[['Dinamico','COLCAP']].copy()
CrediD = np.log(CrediD) - np.log(CrediD.shift(1))
CrediD['Dinamico'] = CrediD['Dinamico'] - data['RiskFree']
CrediD['COLCAP'] = CrediD['COLCAP'] - data['RiskFree'] + data['DividendYield']
CrediD = CrediD.dropna()

# %%
Y1 = CrediD['Dinamico']
X1 = CrediD['COLCAP']
X1 = sm.add_constant(X1)

# %%
modelValor = sm.OLS(Y1,X1).fit()
modelValor.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Dinamico   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.956
# Method:                 Least Squares   F-statistic:                     1260.
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           1.46e-40
# Time:                        22:58:18   Log-Likelihood:                 182.73
# No. Observations:                  59   AIC:                            -361.5
# Df Residuals:                      57   BIC:                            -357.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0006      0.001      0.444      0.658      -0.002       0.004
# ...

# %% [markdown]
# ### Modelo Valor CrediCorp

# %%
ValorCC = data[['ValorCcorp','COLCAP']].copy()
ValorCC = np.log(ValorCC) - np.log(ValorCC.shift(1))
ValorCC['ValorCcorp'] = ValorCC['ValorCcorp'] - data['RiskFree']
ValorCC['COLCAP'] = ValorCC['COLCAP'] - data['RiskFree'] + data['DividendYield']
ValorCC = ValorCC.dropna()

# %%
Y2 = ValorCC['ValorCcorp']
X2 = ValorCC['COLCAP']
X2 = sm.add_constant(X2)

# %%
ValorAcciones = sm.OLS(Y2,X2).fit()
ValorAcciones.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             ValorCcorp   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.319
# Method:                 Least Squares   F-statistic:                     22.59
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           2.08e-05
# Time:                        22:58:25   Log-Likelihood:                 106.34
# No. Observations:                  47   AIC:                            -208.7
# Df Residuals:                      45   BIC:                            -205.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0037      0.004     -0.982      0.331      -0.011       0.004
# ...

# %% [markdown]
# ### Modelo Acciones Bancolombia

# %%
Bancol = data[['AccionesBancol','COLCAP']].copy()
Bancol = np.log(Bancol) - np.log(Bancol.shift(1))
Bancol['AccionesBancol'] = Bancol['AccionesBancol'] - data['RiskFree']
Bancol['COLCAP'] = Bancol['COLCAP'] - data['RiskFree'] + data['DividendYield']
Bancol = Bancol.dropna()

# %%
Y3 = Bancol['AccionesBancol']
X3 = Bancol['COLCAP']
X3 = sm.add_constant(X3)

# %%
ValorBancol = sm.OLS(Y3,X3).fit()
ValorBancol.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:         AccionesBancol   R-squared:                       0.964
# Model:                            OLS   Adj. R-squared:                  0.963
# Method:                 Least Squares   F-statistic:                     1531.
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           6.99e-43
# Time:                        22:58:30   Log-Likelihood:                 188.89
# No. Observations:                  59   AIC:                            -373.8
# Df Residuals:                      57   BIC:                            -369.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0012      0.001     -0.901      0.372      -0.004       0.001
# ...

# %% [markdown]
# ### Modelo Colombia BTG

# %%
BTG = data[['ColombiaBTG','COLCAP']].copy()
BTG = np.log(BTG) - np.log(BTG.shift(1))
BTG['ColombiaBTG'] = BTG['ColombiaBTG'] - data['RiskFree']
BTG['COLCAP'] = BTG['COLCAP'] - data['RiskFree'] + data['DividendYield']
BTG = BTG.dropna()

# %%
Y4 = BTG['ColombiaBTG']
X4 = BTG['COLCAP']
X4 = sm.add_constant(X4)

# %%
ModelBTG = sm.OLS(Y4,X4).fit()
ModelBTG.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            ColombiaBTG   R-squared:                       0.967
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     967.8
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           4.97e-26
# Time:                        22:58:32   Log-Likelihood:                 109.00
# No. Observations:                  35   AIC:                            -214.0
# Df Residuals:                      33   BIC:                            -210.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.002      0.173      0.864      -0.004       0.004
# ...

# %% [markdown]
# ### Modelo Davivienda

# %%
Davi = data[['DaviviendaC','COLCAP']].copy()
Davi = np.log(Davi) - np.log(Davi.shift(1))
Davi['DaviviendaC'] = Davi['DaviviendaC'] - data['RiskFree']
Davi['COLCAP'] = Davi['COLCAP'] - data['RiskFree'] + data['DividendYield']
Davi = Davi.dropna()

# %%
Y4 = Davi['DaviviendaC']
X4 = Davi['COLCAP']
X4 = sm.add_constant(X4)

# %%
ModelDavi = sm.OLS(Y4,X4).fit()
ModelDavi.summary()
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:1769: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            DaviviendaC   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.969
# Method:                 Least Squares   F-statistic:                     532.3
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           1.05e-13
# Time:                        22:58:35   Log-Likelihood:                 54.572
# No. Observations:                  18   AIC:                            -105.1
# Df Residuals:                      16   BIC:                            -103.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ### Modelo Ultraserfinco

# %%
Ultra = data[['Ultraserfinc','COLCAP']].copy()
Ultra = np.log(Ultra) - np.log(Ultra.shift(1))
Ultra['Ultraserfinc'] = Ultra['Ultraserfinc'] - data['RiskFree']
Ultra['COLCAP'] = Ultra['COLCAP'] - data['RiskFree'] + data['DividendYield']
Ultra = Ultra.dropna()

# %%
Y5 = Ultra['Ultraserfinc']
X5 = Ultra['COLCAP']
X5 = sm.add_constant(X5)

# %%
ModelUltra = sm.OLS(Y5,X5).fit()
ModelUltra.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Ultraserfinc   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.959
# Method:                 Least Squares   F-statistic:                     1262.
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           1.22e-38
# Time:                        22:58:38   Log-Likelihood:                 174.63
# No. Observations:                  55   AIC:                            -345.3
# Df Residuals:                      53   BIC:                            -341.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0020      0.001     -1.466      0.148      -0.005       0.001
# ...

# %% [markdown]
# ### Modelo PlusCorficol

# %%
PlusC = data[['Pcorfi','COLCAP']].copy()
PlusC = np.log(PlusC) - np.log(PlusC.shift(1))
PlusC['Pcorfi'] = PlusC['Pcorfi'] - data['RiskFree']
PlusC['COLCAP'] = PlusC['COLCAP'] - data['RiskFree'] + data['DividendYield']
PlusC = PlusC.dropna()
PlusC
# Out:
#               Pcorfi    COLCAP
# Fecha
# 2019-05-31 -0.061158 -0.057227
# 2019-06-30  0.033565  0.040565
# 2019-07-31  0.003229  0.007564
# 2019-08-31 -0.005898 -0.002270
# 2019-09-30  0.004609  0.011096
# 2019-10-31  0.032146  0.033634
# 2019-11-30 -0.015381 -0.013608
# 2019-12-31  0.029757  0.030434
# 2020-01-31 -0.024219 -0.023911
# 2020-02-29 -0.051960 -0.046616
# 2020-03-31 -0.326215 -0.319789
# 2020-04-30  0.031132  0.017753
# 2020-05-31 -0.031187 -0.038956
# 2020-06-30  0.003166  0.016839
# 2020-07-31  0.021172  0.022808
# 2020-08-31  0.054561  0.072164
# 2020-09-30 -0.040914 -0.033850
# 2020-10-31 -0.021801 -0.027037

# %%
Y6 = PlusC['Pcorfi']
X6 = PlusC['COLCAP']
X6 = sm.add_constant(X6)

# %%
ModelPlus = sm.OLS(Y6,X6).fit()
ModelPlus.summary()
# Out:
# C:\Users\camil\anaconda3\lib\site-packages\scipy\stats\_stats_py.py:1769: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=18
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Pcorfi   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     2155.
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           1.71e-18
# Time:                        22:59:54   Log-Likelihood:                 63.985
# No. Observations:                  18   AIC:                            -124.0
# Df Residuals:                      16   BIC:                            -122.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# # Fondos de Renta Fija

# %%
Fi = pd.read_excel("DatosTaller1.xlsx", sheet_name = 1,index_col = 0)
Fi.head()
# Out:
#                  Fonval    fiducuenta   rentabancol  Fidurentabancol  \
# Fecha
# 2015-11-30  3538.771973  24385.080078  11825.129883     25923.339844
# 2015-12-31  3552.418945  24490.300781  11874.589844     26043.320313
# 2016-01-31  3566.756104  24595.000000  11923.080078     26145.369141
# 2016-02-29  3582.071045  24699.150391  11978.150391     26251.000000
# 2016-03-31  3602.498047  24839.820313  12048.019531     26452.550781
#
#                Rentafija       rfcredi  DividendYield  RiskFree        CTCP
# Fecha
# 2015-11-30  20900.939453  10159.820313              0       NaN  189.460007
# 2015-12-31  20993.039063  10159.820313              0  0.004472  188.919998
# 2016-01-31  21077.230469  10164.690430              0  0.004629  188.789993
# 2016-02-29  21158.419922  10161.719727              0  0.004991  189.139999
# 2016-03-31  21305.109375  10311.200195              0  0.005219  193.279999

# %% [markdown]
# ### Modelo Fonval

# %%
FonvalCr = Fi[['Fonval','CTCP']].copy()
FonvalCr = np.log(FonvalCr) - np.log(FonvalCr.shift(1))
FonvalCr['Fonval'] = FonvalCr['Fonval'] - Fi['RiskFree']
FonvalCr['CTCP'] = FonvalCr['CTCP'] - Fi['RiskFree']
FonvalCr = FonvalCr.dropna()

# %%
Y7 = FonvalCr['Fonval']
X7 = FonvalCr['CTCP']
X7 = sm.add_constant(X7)

# %%
ModelFonval = sm.OLS(Y7,X7).fit()
ModelFonval.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Fonval   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.294
# Method:                 Least Squares   F-statistic:                     25.11
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           5.57e-06
# Time:                        21:30:32   Log-Likelihood:                 326.27
# No. Observations:                  59   AIC:                            -648.5
# Df Residuals:                      57   BIC:                            -644.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.000     -3.670      0.001      -0.001      -0.000
# ...

# %% [markdown]
# ### Modelo Fiducuenta

# %%
Fiduc = Fi[['fiducuenta','CTCP']].copy()
Fiduc = np.log(Fiduc) - np.log(Fiduc.shift(1))
Fiduc['fiducuenta'] = Fiduc['fiducuenta'] - Fi['RiskFree']
Fiduc['CTCP'] = Fiduc['CTCP'] - Fi['RiskFree']
Fiduc = Fiduc.dropna()

# %%
Y8 = Fiduc['fiducuenta']
X8 = Fiduc['CTCP']
X8 = sm.add_constant(X8)

# %%
ModelFiduc = sm.OLS(Y8,X8).fit()
ModelFiduc.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             fiducuenta   R-squared:                       0.381
# Model:                            OLS   Adj. R-squared:                  0.370
# Method:                 Least Squares   F-statistic:                     35.06
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           1.93e-07
# Time:                        21:30:32   Log-Likelihood:                 349.55
# No. Observations:                  59   AIC:                            -695.1
# Df Residuals:                      57   BIC:                            -690.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003   8.97e-05     -3.714      0.000      -0.001      -0.000
# ...

# %% [markdown]
# ### Modelo Renta Liquidez

# %%
Rentab = Fi[['rentabancol','CTCP']].copy()
Rentab = np.log(Rentab) - np.log(Rentab.shift(1))
Rentab['rentabancol'] = Rentab['rentabancol'] - Fi['RiskFree']
Rentab['CTCP'] = Rentab['CTCP'] - Fi['RiskFree']
Rentab = Rentab.dropna()

# %%
Y9 = Rentab['rentabancol']
X9 = Rentab['CTCP']
X9 = sm.add_constant(X9)

# %%
ModelRLB = sm.OLS(Y9,X9).fit()
ModelRLB.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            rentabancol   R-squared:                       0.469
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     50.43
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           2.16e-09
# Time:                        21:30:32   Log-Likelihood:                 344.88
# No. Observations:                  59   AIC:                            -685.8
# Df Residuals:                      57   BIC:                            -681.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003   9.71e-05     -3.130      0.003      -0.000      -0.000
# ...

# %% [markdown]
# ### Modelo Fidurenta

# %%
Fiduren = Fi[['Fidurentabancol','CTCP']].copy()
Fiduren = np.log(Fiduren) - np.log(Fiduren.shift(1))
Fiduren['Fidurentabancol'] = Fiduren['Fidurentabancol'] - Fi['RiskFree']
Fiduren['CTCP'] = Fiduren['CTCP'] - Fi['RiskFree']
Fiduren = Fiduren.dropna()

# %%
Y10 = Fiduren['Fidurentabancol']
X10 = Fiduren['CTCP']
X10 = sm.add_constant(X10)

# %%
ModelRLB = sm.OLS(Y10,X10).fit()
ModelRLB.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Fidurentabancol   R-squared:                       0.529
# Model:                            OLS   Adj. R-squared:                  0.521
# Method:                 Least Squares   F-statistic:                     64.01
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           6.86e-11
# Time:                        21:30:32   Log-Likelihood:                 289.98
# No. Observations:                  59   AIC:                            -576.0
# Df Residuals:                      57   BIC:                            -571.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.606      0.114   -9.78e-05       0.001
# ...

# %% [markdown]
# ### Modelo Renta Fija a Bancol

# %%
RFB = Fi[['Rentafija','CTCP']].copy()
RFB = np.log(RFB) - np.log(RFB.shift(1))
RFB['Rentafija'] = RFB['Rentafija'] - Fi['RiskFree']
RFB['CTCP'] = RFB['CTCP'] - Fi['RiskFree']
RFB = RFB.dropna()

# %%
Y12 = RFB['Rentafija']
X12 = RFB['CTCP']
X12 = sm.add_constant(X12)

# %%
ModelRLB = sm.OLS(Y12,X11).fit()
ModelRLB.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Rentafija   R-squared:                       0.547
# Model:                            OLS   Adj. R-squared:                  0.539
# Method:                 Least Squares   F-statistic:                     68.82
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           2.22e-11
# Time:                        23:12:32   Log-Likelihood:                 227.28
# No. Observations:                  59   AIC:                            -450.6
# Df Residuals:                      57   BIC:                            -446.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.001      0.760      0.450      -0.001       0.002
# ...

# %% [markdown]
# ### Modelo Renta Fija Credicorp Capital

# %%
RFC = Fi[['rfcredi','CTCP']].copy()
RFC = np.log(RFC) - np.log(RFC.shift(1))
RFC['rfcredi'] = RFC['rfcredi'] - Fi['RiskFree']
RFC['CTCP'] = RFC['CTCP'] - Fi['RiskFree']
RFC = RFC.dropna()

# %%
Y11 = RFC['rfcredi']
X11 = RFC['CTCP']
X11 = sm.add_constant(X11)

# %%
ModelRLB = sm.OLS(Y11,X11).fit()
ModelRLB.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                rfcredi   R-squared:                       0.529
# Model:                            OLS   Adj. R-squared:                  0.521
# Method:                 Least Squares   F-statistic:                     64.11
# Date:                Mon, 19 Feb 2024   Prob (F-statistic):           6.70e-11
# Time:                        21:43:44   Log-Likelihood:                 204.27
# No. Observations:                  59   AIC:                            -404.5
# Df Residuals:                      57   BIC:                            -400.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0003      0.001      0.286      0.776      -0.002       0.002
# ...

# %% [markdown]
# ## Modelos con datos actualizados

# %%
datosN = pd.read_excel("Datos_aldia.xlsx", index_col = 0)
datosN.head()
# Out:
#             Dinamico  AccionesBancol  ColombiaBTG  DaviviendaC  Ultraserfinc  \
# Dates
# 2020-11-30  12846.42        53072.93     19014.70      9085.20       1870.74
# 2020-12-31  14668.01        60960.78     21896.31     10488.99       2130.45
# 2021-01-31  13726.35        57090.34     20448.65      9785.28       2004.70
# 2021-02-28  13940.18        57418.28     20520.51      9911.13       2023.56
# 2021-03-31  13377.82        55045.20     19763.37      9555.06       1958.88
#
#               Pcorfi  Riskfree   COLCAP
# Dates
# 2020-11-30  0.004331  0.001415  1258.00
# 2020-12-31  0.003487  0.001407  1437.89
# 2021-01-31  0.003741  0.001410  1348.12
# 2021-02-28  0.003706  0.001405  1359.48
# 2021-03-31  0.003396  0.001391  1316.81

# %%
RV = datosN[['Dinamico','COLCAP']].copy()
RV = np.log(RV) - np.log(RV.shift(1))
RV = RV['Dinamico'] - datosN['Riskfree']
RV['COLCAP'] = RV['COLCAP'] - datosN['Riskfree']
#RV = RFC.dropna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: Unknown datetime string format, unable to parse: COLCAP
#
# During handling of the above exception, another exception occurred:
#
# DateParseError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\datetimes.py in get_loc(self, key, method, tolerance)
#     660             try:
# --> 661                 parsed, reso = self._parse_with_reso(key)
#     662             except ValueError as err:
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\datetimelike.py in _parse_with_reso(self, label)
# ...
